# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("uber.csv")
df.head()
# Out:
#           Date/Time      Lat      Lon    Base
# 0  4/1/2014 0:11:00  40.7690 -73.9549  B02512
# 1  4/1/2014 0:17:00  40.7267 -74.0345  B02512
# 2  4/1/2014 0:21:00  40.7316 -73.9873  B02512
# 3  4/1/2014 0:28:00  40.7588 -73.9776  B02512
# 4  4/1/2014 0:33:00  40.7594 -73.9722  B02512

# %%
df.isnull().sum()
# Out:
# Date/Time    0
# Lat          0
# Lon          0
# Base         0
# dtype: int64

# %%
## means data is clean

# %%
df.dtypes
# Out:
# Date/Time     object
# Lat          float64
# Lon          float64
# Base          object
# dtype: object

# %%
df["Date/Time"]=pd.to_datetime(df["Date/Time"])

# %%
df["hour"]=df["Date/Time"].dt.hour

# %%
df.head()
# Out:
#             Date/Time      Lat      Lon    Base  hour
# 0 2014-04-01 00:11:00  40.7690 -73.9549  B02512     0
# 1 2014-04-01 00:17:00  40.7267 -74.0345  B02512     0
# 2 2014-04-01 00:21:00  40.7316 -73.9873  B02512     0
# 3 2014-04-01 00:28:00  40.7588 -73.9776  B02512     0
# 4 2014-04-01 00:33:00  40.7594 -73.9722  B02512     0

# %%
df["day"]=df["Date/Time"].dt.day
plt.figure(figsize=(8,5),dpi=100)
df.groupby("day")["day"].count().plot(kind="bar")
plt.xlabel("day",fontsize=15)
plt.ylabel("no of traveller",fontsize=15)
plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5),dpi=100)
df.groupby("hour")["hour"].count().plot(kind="bar")
x=df.groupby("hour").sum().reset_index()
plt.grid()
plt.xticks(x["hour"])
plt.xlabel("hour",fontsize=15,color="blue")
plt.ylabel("no of travelling",fontsize=15,color="blue")
plt.show()

# %%
df["dayofweek"]=df["Date/Time"].dt.weekday ###0 for monday

# %%
df.shape
# Out:
# (564516, 6)

# %%
plt.figure(figsize=(8,5),dpi=100)
df.groupby("dayofweek")["dayofweek"].count().plot(kind="bar")
#plt.xticks(["Mon","Tue","Wed","Thru","Fri","Sat","Sun"])
plt.xlabel("day",fontsize=15)
plt.ylabel("no of travelling",fontsize=15)
plt.show()

# %%
plt.figure(figsize=(8,5),dpi=100)
#df.groupby("dayofweek")["dayofweek"].count().plot(kind="bar")
x=["Mon","Tue","Wed","Thru","Fri","Sat","Sun"]
plt.bar(x,df.groupby("dayofweek")["dayofweek"].count())
plt.xlabel("day",fontsize=15)
plt.ylabel("no of travelling",fontsize=15)
plt.show()

# %%
df["min"]=df["Date/Time"].dt.minute

# %%
plt.figure(figsize=(12,5),dpi=100)
df.groupby("min")["min"].count().plot(kind="bar")
plt.xticks(rotation="vertical")
plt.xlabel("Min of hour")
plt.ylabel("Toatl travellers")
plt.show()
